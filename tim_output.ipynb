# %%
import pandas as pd

# %%
df = pd.read_csv('tim.csv')

# %%
df[df['tim'].str.contains('unknown')]
# Out:
#            namelist       dom  isec  item        tim    use
# 5    00407_32c04ea2  'DALLTH'     0   407  'unknown'  'UP5'
# 7    00408_7edf6a73  'DALLTH'     0   408  'unknown'  'UP5'
# 8    00408_9d06a3e9  'DALLTH'     0   408  'unknown'  'UP7'
# 20   02181_497b5ba6  'DALLTH'     2   181  'unknown'  'UP5'
# 108  16222_2a8515be    'DIAG'    16   222  'unknown'  'UP7'
# 124  30201_04eba325   'DP850'    30   201  'unknown'  'UP6'
# 125  30201_12d09e8f   'DP200'    30   201  'unknown'  'UP7'
# 127  30201_dce7b9a9   'DP850'    30   201  'unknown'  'UP7'
# 128  30201_e89a47fc   'DP200'    30   201  'unknown'  'UP6'
# 129  30201_fb54a40c   'PLEV3'    30   201  'unknown'  'UP7'
# 130  30202_34c2772a   'DP850'    30   202  'unknown'  'UP6'
# 131  30202_51eec0e6   'DP200'    30   202  'unknown'  'UP6'
# 132  30202_5bffdfd0   'DP200'    30   202  'unknown'  'UP7'
# 133  30202_ac2b5056   'PLEV3'    30   202  'unknown'  'UP7'
# 135  30294_6d1dd71d   'PLEV3'    30   294  'unknown'  'UP7'
# ...

# %%
df[df['use'].str.contains('UNKNOWN')][df['tim'].str.contains('UNKNOWN')]
# Out:
# /home/vagrant/miniconda2/envs/pandas/lib/python2.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#           namelist        dom  isec  item        tim        use
# 37  02321_286263eb     'DIAG'     2   321  'UNKNOWN'  'UNKNOWN'
# 38  02322_0376c598     'DIAG'     2   322  'UNKNOWN'  'UNKNOWN'
# 41  02323_8fc5dba8     'DIAG'     2   323  'UNKNOWN'  'UNKNOWN'
# 42  02324_918d6e83     'DIAG'     2   324  'UNKNOWN'  'UNKNOWN'
# 44  02325_3c7ff5c8  'DCOSP40'     2   325  'UNKNOWN'  'UNKNOWN'
# 49  02344_2829f04f     'DIAG'     2   344  'UNKNOWN'  'UNKNOWN'
# 51  02345_fe9da8f9     'DIAG'     2   345  'UNKNOWN'  'UNKNOWN'
# 52  02346_4b03746d     'DIAG'     2   346  'UNKNOWN'  'UNKNOWN'
# 54  02347_4d26f8cd     'DIAG'     2   347  'UNKNOWN'  'UNKNOWN'
# 57  02370_bfa84836  'DCOSP40'     2   370  'UNKNOWN'  'UNKNOWN'
# 58  02371_262bea68  'DCOSP40'     2   371  'UNKNOWN'  'UNKNOWN'
# ...

# %%
df[df['use'].str.contains('UNKNOWN')][df['tim'].str.contains('UNKNOWN')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-f5a8f9ac834d> in <module>()
# ----> 1 df[not df['use'].str.contains('UNKNOWN')][df['tim'].str.contains('UNKNOWN')]
#
# /home/vagrant/miniconda2/envs/pandas/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     915         raise ValueError("The truth value of a {0} is ambiguous. "
#     916                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 917                          .format(self.__class__.__name__))
#     918
#     919     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
